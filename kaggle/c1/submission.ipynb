# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.io as pio
from plotly.subplots import make_subplots

# import warnings
# warnings.filterwarnings('ignore')

# %% [markdown]
# ***All Common***

# %%
def find_values_diff(col1, col2):    
    col1_col2 = np.setdiff1d(col1, col2)
    col2_col1 = np.setdiff1d(col2, col1)
    
    return np.concatenate((col1_col2, col2_col1))

# %% [markdown]
# #### Начнем исследовать данные
#
# Посмотрю на каждую таблицу и кратенько отмечую интересные моменты

# %%
assessments = pd.read_csv('assessments.csv') # Информация об оценках в модулях
resultAssessments = pd.read_csv('studentAssessment.csv') # Сами оценки
courses = pd.read_csv('courses.csv') # Список модулей
studentInfo = pd.read_csv('studentInfo.csv') # Общее инфо о студенте
registration = pd.read_csv('studentRegistration.csv') # Инфа о регистрации студента на модули
studentVle = pd.read_csv('studentVle.csv') # Взаимодействие студента с виртуальной средой обучения
vle = pd.read_csv('vle.csv') # Доступные материалы в виртуальной среде обучения

# %% [markdown]
# ##### Сначала глянем assessments и resultAssessments

# %%
# assessments
print(assessments.info())
assessments.sample(7)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206 entries, 0 to 205
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   code_module        206 non-null    object
#  1   code_presentation  206 non-null    object
#  2   id_assessment      206 non-null    int64
#  3   assessment_type    206 non-null    object
#  4   date               195 non-null    float64
#  5   weight             206 non-null    float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 9.8+ KB
# None
#     code_module code_presentation  id_assessment assessment_type   date
# 136         FFF             2013B          34872            Exam  222.0  \
# 111         EEE             2013J          30711             TMA  124.0
# 181         GGG             2013J          37423             CMA  229.0
# 164         FFF             2014J          34905             CMA  241.0
# 204         GGG             2014J          37437             TMA  173.0
# 151         FFF             2014B          34892             CMA  227.0
# 82          DDD             2013B          25335             TMA   53.0
#
#      weight
# 136   100.0
# 111    28.0
# 181     0.0
# 164     0.0
# 204     0.0
# 151     0.0
# 82     10.0

# %%
# resultAssessments
print(resultAssessments.info()) # Без пропусков - это хорошо
resultAssessments.sample(7)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173912 entries, 0 to 173911
# Data columns (total 4 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   id_assessment   173912 non-null  int64
#  1   id_student      173912 non-null  int64
#  2   date_submitted  173912 non-null  int64
#  3   is_banked       173912 non-null  int64
# dtypes: int64(4)
# memory usage: 5.3 MB
# None
#         id_assessment  id_student  date_submitted  is_banked
# 161821          37419      574948             131          0
# 62330           24297      633504             147          0
# 160580          37417      586598             172          0
# 112499          34868     2001665             178          0
# 97370           30710      599478              84          0
# 18503           14998      230081              79          0
# 14972           14996      535833              18          0

# %%
absent_ids = find_values_diff(resultAssessments["id_assessment"], assessments["id_assessment"])
assesments_absent = assessments[assessments["id_assessment"].isin(absent_ids)]
assesments_absent # Остутствуют экзамены
# Out:
#     code_module code_presentation  id_assessment assessment_type   date
# 5           AAA             2013J           1757            Exam    NaN  \
# 11          AAA             2014J           1763            Exam    NaN
# 23          BBB             2013B          14990            Exam    NaN
# 35          BBB             2013J          15002            Exam    NaN
# 47          BBB             2014B          15014            Exam    NaN
# 53          BBB             2014J          15025            Exam    NaN
# 63          CCC             2014B          40087            Exam    NaN
# 73          CCC             2014J          40088            Exam    NaN
# 113         EEE             2013J          30713            Exam  235.0
# 118         EEE             2014B          30718            Exam  228.0
# 123         EEE             2014J          30723            Exam  235.0
# 136         FFF             2013B          34872            Exam  222.0
# 149         FFF             2013J          34885            Exam  236.0
# 162         FFF             2014B          34898            Exam  227.0
# 175         FFF             2014J          34911            Exam  241.0
# 185         GGG             2013J          37424            Exam  229.0
# 195         GGG             2014B          37434            Exam  222.0
# 205         GGG             2014J          37444            Exam  229.0
#
#      weight
# 5     100.0
# 11    100.0
# 23    100.0
# 35    100.0
# 47    100.0
# 53    100.0
# 63    100.0
# 73    100.0
# 113   100.0
# 118   100.0
# 123   100.0
# 136   100.0
# 149   100.0
# 162   100.0
# 175   100.0
# 185   100.0
# 195   100.0
# 205   100.0

# %%
group = assessments.groupby("assessment_type").count()
group[group.index == "Exam"] # Приэтом для каких-то 6 экзаменов оценки есть. Ладно(
# Out:
#                  code_module  code_presentation  id_assessment  date  weight
# assessment_type
# Exam                      24                 24             24    13      24

# %%
# Объединим эти таблицы
assesmentsFullInfo = pd.merge(
    resultAssessments, 
    assessments,
    how="inner",
    on="id_assessment",
    )
assert(
    (len(assessments.columns) + len(resultAssessments.columns) - 1) == len(assesmentsFullInfo.columns)
    )
assert(
    assesmentsFullInfo.shape[0] == resultAssessments.shape[0]
)
print(assesmentsFullInfo.info())
assesmentsFullInfo.sample(7)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173912 entries, 0 to 173911
# Data columns (total 9 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   id_assessment      173912 non-null  int64
#  1   id_student         173912 non-null  int64
#  2   date_submitted     173912 non-null  int64
#  3   is_banked          173912 non-null  int64
#  4   code_module        173912 non-null  object
#  5   code_presentation  173912 non-null  object
#  6   assessment_type    173912 non-null  object
#  7   date               171047 non-null  float64
#  8   weight             173912 non-null  float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 11.9+ MB
# None
#         id_assessment  id_student  date_submitted  is_banked code_module
# 45618           15024      686822             200          0         BBB  \
# 168061          37430      630787             147          0         GGG
# 94745           25367      676373             195          0         DDD
# 66426           25335      371184              53          0         DDD
# 167194          37429      593965             122          0         GGG
# 43533           15022     2248243              98          0         BBB
# 85415           25357      627581              74          0         DDD
#
#        code_presentation assessment_type   date  weight
# 45618              2014J             TMA  201.0    35.0
# 168061             2014B             CMA  222.0     0.0
# 94745              2014J             TMA  195.0    25.0
# 66426              2013B             TMA   53.0    10.0
# 167194             2014B             CMA  222.0     0.0
# 43533              2014J             TMA  110.0    20.0
# 85415              2014B             TMA   74.0    17.5

# %%
print(assesmentsFullInfo["is_banked"].value_counts()) # Выкинем этот признак, у него слишком плохое распределение
assesmentsFullInfoV1 = assesmentsFullInfo.drop("is_banked", axis=1) # Будем версионировать DF чтоб была полная воспроизводимость
# Out:
# is_banked
# 0    172003
# 1      1909
# Name: count, dtype: int64

# %% [markdown]
# ### Объединим с courses

# %%
find_values_diff(
   col1=courses["code_module"] + courses["code_presentation"],
   col2=assesmentsFullInfoV1["code_module"] + assesmentsFullInfoV1["code_presentation"]
) # Ок, можем спокойной мержить

assesmentsFullCourses = pd.merge(
    assesmentsFullInfoV1,
    courses,
    how="inner",
    on=["code_module", "code_presentation"]
)
assert(
    len(assesmentsFullInfoV1.columns) + 1 == len(assesmentsFullCourses.columns)
    )
assert(
    assesmentsFullCourses.shape[0] == assesmentsFullInfoV1.shape[0]
)
assesmentsFullCourses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173912 entries, 0 to 173911
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   id_assessment               173912 non-null  int64
#  1   id_student                  173912 non-null  int64
#  2   date_submitted              173912 non-null  int64
#  3   code_module                 173912 non-null  object
#  4   code_presentation           173912 non-null  object
#  5   assessment_type             173912 non-null  object
#  6   date                        171047 non-null  float64
#  7   weight                      173912 non-null  float64
#  8   module_presentation_length  173912 non-null  int64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 11.9+ MB

# %% [markdown]
# #### Проделаем похожее с таблицами о студентах

# %%
registration.info()
registration.sample(7) # Регистраций сильно меньше чем оценок, это ок тк по каждому модулю может быть несколько оценок
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32593 entries, 0 to 32592
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   code_module        32593 non-null  object
#  1   code_presentation  32593 non-null  object
#  2   id_student         32593 non-null  int64
#  3   date_registration  32548 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 1018.7+ KB
#       code_module code_presentation  id_student  date_registration
# 6790          BBB             2014J      551237              -23.0
# 22588         FFF             2013B      382086              -27.0
# 32051         GGG             2014J      638503              -58.0
# 26406         FFF             2014B      407500              -25.0
# 31683         GGG             2014B      631788               -8.0
# 23595         FFF             2013B      556489              -18.0
# 26318         FFF             2014B      301128             -305.0

# %%
reg_diff = find_values_diff(
   col1=assesmentsFullCourses["code_module"] + assesmentsFullCourses["code_presentation"] + assesmentsFullCourses["id_student"].astype(str),
   col2=registration["code_module"] + registration["code_presentation"] + registration["id_student"].astype(str)
)
len(reg_diff) # Думаю это ок, студенты могли не регистрироваться на курсы вообще
# будем мержить inner, тк если не регистрировался то и не сдавал выходит
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32593 entries, 0 to 32592
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   code_module        32593 non-null  object
#  1   code_presentation  32593 non-null  object
#  2   id_student         32593 non-null  int64
#  3   date_registration  32548 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 1018.7+ KB
# 6750

# %%
assesmentsFullCoursesReg = pd.merge(
    registration,
    assesmentsFullCourses,
    how="inner",
    on=["code_module", "code_presentation", "id_student"]
)
assesmentsFullCoursesReg.info()
assesmentsFullCoursesReg.sample(7)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173912 entries, 0 to 173911
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   code_module                 173912 non-null  object
#  1   code_presentation           173912 non-null  object
#  2   id_student                  173912 non-null  int64
#  3   date_registration           173905 non-null  float64
#  4   id_assessment               173912 non-null  int64
#  5   date_submitted              173912 non-null  int64
#  6   assessment_type             173912 non-null  object
#  7   date                        171047 non-null  float64
#  8   weight                      173912 non-null  float64
#  9   module_presentation_length  173912 non-null  int64
# dtypes: float64(3), int64(4), object(3)
# memory usage: 13.3+ MB
#        code_module code_presentation  id_student  date_registration
# 107299         FFF             2013B      467725              -16.0  \
# 74495          DDD             2013B     2227786              -22.0
# 28524          BBB             2013J     2550290              -58.0
# 69303          DDD             2013B      500136             -151.0
# 73538          DDD             2013B      559612              -16.0
# 109377         FFF             2013B      528075              -21.0
# 649            AAA             2013J      324084             -165.0
#
#         id_assessment  date_submitted assessment_type   date  weight
# 107299          34866              80             CMA  222.0     0.0  \
# 74495           25345             152             CMA  149.0     4.0
# 28524           14997              51             TMA   47.0    18.0
# 69303           25343              81             CMA   79.0     3.0
# 73538           25342              54             CMA   51.0     3.0
# 109377          34869             171             CMA  222.0     0.0
# 649              1755             166             TMA  166.0    20.0
#
#         module_presentation_length
# 107299                         240
# 74495                          240
# 28524                          268
# 69303                          240
# 73538                          240
# 109377                         240
# 649                            268

# %% [markdown]
# ##### Объединим с инфой о студенте

# %%
studentInfo.info()
studentInfo.sample(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32593 entries, 0 to 32592
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   code_module           32593 non-null  object
#  1   code_presentation     32593 non-null  object
#  2   id_student            32593 non-null  int64
#  3   gender                32593 non-null  object
#  4   region                32593 non-null  object
#  5   highest_education     32593 non-null  object
#  6   imd_band              31482 non-null  object
#  7   age_band              32593 non-null  object
#  8   num_of_prev_attempts  32593 non-null  int64
#  9   studied_credits       32593 non-null  int64
#  10  disability            32593 non-null  object
# dtypes: int64(3), object(8)
# memory usage: 2.7+ MB
#       code_module code_presentation  id_student gender               region
# 5818          BBB             2014B      624738      M     Yorkshire Region  \
# 23299         FFF             2013B      543536      M              Ireland
# 15414         DDD             2013J      572648      M              Ireland
# 25872         FFF             2013J      608169      M                Wales
# 31184         GGG             2014B      578845      F         North Region
# 27568         FFF             2014B     1738364      M         South Region
# 2251          BBB             2013B      558602      F  East Anglian Region
# 16843         DDD             2014B      587403      M                Wales
# 27222         FFF             2014B      626692      M  East Anglian Region
# 21701         EEE             2014J      649843      M        London Region
#
#            highest_education imd_band age_band  num_of_prev_attempts
# 5818      Lower Than A Level    10-20     0-35                     0  \
# 23299     Lower Than A Level   50-60%     0-35                     0
# 15414  A Level or Equivalent    10-20     0-35                     0
# 25872       HE Qualification   40-50%    35-55                     0
# 31184  A Level or Equivalent    10-20     0-35                     0
# 27568       HE Qualification  90-100%    35-55                     0
# 2251      Lower Than A Level   30-40%     0-35                     0
# 16843  A Level or Equivalent   80-90%     0-35                     1
# 27222     Lower Than A Level   50-60%     0-35                     0
# 21701  A Level or Equivalent    10-20     0-35                     0
#
#        studied_credits disability
# 5818                60          N
# 23299              150          N
# 15414               60          N
# 25872               90          N
# 31184               30          N
# 27568               60          N
# 2251                60          N
# 16843              210          Y
# 27222               60          N
# 21701               60          N

# %%
students_diff = find_values_diff(
   col1=assesmentsFullCoursesReg["code_module"] + assesmentsFullCoursesReg["code_presentation"] + assesmentsFullCoursesReg["id_student"].astype(str),
   col2=studentInfo["code_module"] + studentInfo["code_presentation"] + studentInfo["id_student"].astype(str)
)
len(students_diff) # Такая же картина как с регистрациями - это логично
# Out:
# 6750

# %%
assesmentsCoursesRegStudentInfo = pd.merge(
    assesmentsFullCoursesReg,
    studentInfo,
    how="inner",
    on=["code_module", "code_presentation", "id_student"]
)
assesmentsCoursesRegStudentInfo.info() # Shape ok
assesmentsCoursesRegStudentInfo.sample(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173912 entries, 0 to 173911
# Data columns (total 18 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   code_module                 173912 non-null  object
#  1   code_presentation           173912 non-null  object
#  2   id_student                  173912 non-null  int64
#  3   date_registration           173905 non-null  float64
#  4   id_assessment               173912 non-null  int64
#  5   date_submitted              173912 non-null  int64
#  6   assessment_type             173912 non-null  object
#  7   date                        171047 non-null  float64
#  8   weight                      173912 non-null  float64
#  9   module_presentation_length  173912 non-null  int64
#  10  gender                      173912 non-null  object
#  11  region                      173912 non-null  object
#  12  highest_education           173912 non-null  object
#  13  imd_band                    166215 non-null  object
#  14  age_band                    173912 non-null  object
#  15  num_of_prev_attempts        173912 non-null  int64
#  16  studied_credits             173912 non-null  int64
#  17  disability                  173912 non-null  object
# dtypes: float64(3), int64(6), object(9)
# memory usage: 23.9+ MB
#        code_module code_presentation  id_student  date_registration
# 164957         GGG             2014B      365084               -8.0  \
# 53383          CCC             2014B     2486769             -154.0
# 121489         FFF             2013J      559979             -149.0
# 140177         FFF             2014B      630655              -28.0
# 26265          BBB             2013J      606572              -30.0
# 8597           BBB             2013B      534983              -77.0
# 66987          DDD             2013B      361209              -30.0
# 33687          BBB             2014B      613299             -144.0
# 108797         FFF             2013B      519472              -36.0
# 104920         FFF             2013B      244114              -52.0
#
#         id_assessment  date_submitted assessment_type   date  weight
# 164957          37426             117             TMA  117.0     0.0  \
# 53383           24287              69             CMA   67.0     7.0
# 121489          34882             182             CMA  236.0     0.0
# 140177          34889             129             TMA  129.0    25.0
# 26265           14999             131             TMA  131.0    18.0
# 8597            14985              48             TMA   47.0    18.0
# 66987           25336              79             TMA   81.0    12.5
# 33687           15009              39             TMA   40.0    18.0
# 108797          34867             164             CMA  222.0     0.0
# 104920          34860              18             TMA   19.0    12.5
#
#         module_presentation_length gender                region
# 164957                         241      F          South Region  \
# 53383                          241      M         London Region
# 121489                         268      F   East Anglian Region
# 140177                         241      M              Scotland
# 26265                          268      F  West Midlands Region
# 8597                           240      F  West Midlands Region
# 66987                          240      M      Yorkshire Region
# 33687                          234      F  West Midlands Region
# 108797                         240      M  West Midlands Region
# 104920                         240      M  West Midlands Region
#
#             highest_education imd_band age_band  num_of_prev_attempts
# 164957  A Level or Equivalent   30-40%    35-55                     0  \
# 53383        HE Qualification    0-10%    35-55                     0
# 121489       HE Qualification   20-30%     0-35                     0
# 140177  A Level or Equivalent   30-40%     0-35                     0
# 26265   A Level or Equivalent    0-10%    35-55                     0
# 8597    A Level or Equivalent   50-60%     0-35                     0
# 66987   A Level or Equivalent    0-10%     0-35                     1
# 33687      Lower Than A Level   20-30%     0-35                     0
# 108797  A Level or Equivalent   30-40%     0-35                     0
# 104920     Lower Than A Level   60-70%     0-35                     0
#
#         studied_credits disability
# 164957               30          N
# 53383                90          N
# 121489               90          N
# 140177               60          N
# 26265               120          N
# 8597                120          N
# 66987               180          N
# 33687                60          N
# 108797               60          N
# 104920               60          N

# %% [markdown]
# ### Инфо о взаимодействии с материалами попробуем сгруппировать

# %%
vle[["week_from", "week_to"]].count() # Эти признаки рассматривать не будем их меньше 20%
vleV1 = vle.drop(["week_from", "week_to"], axis=1)
vleV1.sample(10)
# Out:
#       id_site code_module code_presentation  activity_type
# 2163   547305         DDD             2013B   externalquiz
# 3949   832669         EEE             2014J      oucontent
# 4895   716981         FFF             2013J  oucollaborate
# 1536   913678         BBB             2014J       resource
# 6145   798674         GGG             2014B      oucontent
# 3172   773100         DDD             2014B        subpage
# 4075   527311         FFF             2013B            url
# 1517   913481         BBB             2014J      oucontent
# 1514   913613         BBB             2014J       resource
# 5260   779427         FFF             2014B      oucontent

# %%
vleV1["activity_type"].value_counts() # Сомнительная конечно таблица, но ок оставим
# Out:
# activity_type
# resource          2660
# subpage           1055
# oucontent          996
# url                886
# forumng            194
# quiz               127
# page               102
# oucollaborate       82
# questionnaire       61
# ouwiki              49
# dataplus            28
# externalquiz        26
# homepage            22
# ouelluminate        21
# glossary            21
# dualpane            20
# repeatactivity       5
# htmlactivity         4
# sharedsubpage        3
# folder               2
# Name: count, dtype: int64

# %%
studentVle.info()
studentVle.sample(7)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10655280 entries, 0 to 10655279
# Data columns (total 6 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   code_module        object
#  1   code_presentation  object
#  2   id_student         int64
#  3   id_site            int64
#  4   date               int64
#  5   sum_click          int64
# dtypes: int64(4), object(2)
# memory usage: 487.8+ MB
#          code_module code_presentation  id_student  id_site  date  sum_click
# 10345377         GGG             2013J      569679   661599   146          3
# 1287804          BBB             2014B      477779   768521    37          1
# 8454550          FFF             2014B      633403   779556     6          1
# 5925006          EEE             2014J      684907   832660    19          2
# 4980472          DDD             2014J     2423655   813954    62          1
# 9336295          FFF             2014J     1818385   882553    23          1
# 5882621          EEE             2014J      574565   832668     4          1

# %%
find_values_diff(studentVle["id_site"], vleV1["id_site"]) # Есть относительно небольшое кол-во пропусков
# Out:
# array([ 526733,  526818,  527224,  527386,  527399,  527404,  527493,
#         527506,  546872,  546897,  547278,  547638,  547639,  547646,
#         547648,  547663,  547668,  547682,  547684,  547689,  547692,
#         547693,  547718,  547733,  547742,  547771,  547782,  547800,
#         547941,  547969,  551014,  551036,  551124,  551159,  551169,
#         673527,  673529,  673535,  674130,  674323,  674324,  703977,
#         716221,  716675,  716987,  729799,  729803,  729805,  729808,
#         729824,  729831,  729835,  729836,  729837,  729838,  729839,
#         729840,  729845,  730034,  779622,  790925,  813957,  832764,
#         877133,  883074,  909241,  913688,  923834,  923835,  924208,
#         924209,  924210,  924211,  924222,  924225,  924383,  924387,
#         924388,  936658,  936659,  936763, 1027118, 1032910, 1071060,
#        1072098, 1072099, 1072100, 1072236, 1072237, 1072239, 1072240,
#        1072252, 1072253, 1073191, 1076553, 1077905])

# %%
studentInteractions = pd.merge(
    studentVle,
    vleV1,
    how="inner",
    on=["id_site", "code_module", "code_presentation"]
)
assert(studentInteractions.shape[1] == (studentVle.shape[1] + 1)) # Добавили только activity_type

# %% [markdown]
# ## Преобразуем данные

# %%
studentInteractions.sample(10) # Предлагается поступить глупо и посчитать общее кол-во взаимодействий с модулем
# Out:
#         code_module code_presentation  id_student  id_site  date  sum_click
# 7198028         FFF             2013B      193834   527420   215          1  \
# 463305          BBB             2013B      555695   543091    -8          1
# 8945819         FFF             2014B      544593   779429    94          1
# 2177058         CCC             2014B      282193   729678    31          1
# 9204806         FFF             2014J      652064   882670    11          4
# 9607693         FFF             2014J      412353   882985     8          2
# 4433718         DDD             2014B      629822   773182     2          2
# 5768215         EEE             2014B      633544   790856   108          1
# 3114947         CCC             2014J      347809  1010405   208          2
# 2889862         CCC             2014J      585769   909020    99          1
#
#         activity_type
# 7198028      resource
# 463305       resource
# 8945819     oucontent
# 2177058       forumng
# 9204806     oucontent
# 9607693      resource
# 4433718       subpage
# 5768215     oucontent
# 3114947      resource
# 2889862       forumng

# %%
assesmentsCoursesRegStudentInfo.sample(10)
# Out:
#        code_module code_presentation  id_student  date_registration
# 12705          BBB             2013B      559389              -24.0  \
# 36179          BBB             2014B      628982              -30.0
# 159136         GGG             2013J      352382              -53.0
# 123142         FFF             2013J      573152              -30.0
# 140226         FFF             2014B      630830              -29.0
# 26167          BBB             2013J      606410              -22.0
# 66389          DDD             2013B      283618              -17.0
# 35309          BBB             2014B      625167              -29.0
# 20958          BBB             2013J      571681             -191.0
# 47998          CCC             2014B      485604              -54.0
#
#         id_assessment  date_submitted assessment_type   date  weight
# 12705           14984              17             TMA   19.0     5.0  \
# 36179           15009              40             TMA   40.0    18.0
# 159136          37422             207             CMA  229.0     0.0
# 123142          34880             118             CMA  236.0     0.0
# 140226          34886              19             TMA   24.0    12.5
# 26167           15005             133             CMA  131.0     1.0
# 66389           25341              25             CMA   23.0     2.0
# 35309           15009              39             TMA   40.0    18.0
# 20958           15006             168             CMA  166.0     1.0
# 47998           24288             139             CMA  137.0     8.0
#
#         module_presentation_length gender                region
# 12705                          240      F          South Region  \
# 36179                          234      F                 Wales
# 159136                         261      F      Yorkshire Region
# 123142                         268      M      Yorkshire Region
# 140226                         241      M          North Region
# 26167                          268      M               Ireland
# 66389                          240      M  West Midlands Region
# 35309                          234      F                 Wales
# 20958                          268      F               Ireland
# 47998                          241      F         London Region
#
#             highest_education imd_band age_band  num_of_prev_attempts
# 12705      Lower Than A Level   80-90%     0-35                     0  \
# 36179        HE Qualification    0-10%     0-35                     0
# 159136  A Level or Equivalent   70-80%    35-55                     0
# 123142  A Level or Equivalent   20-30%     0-35                     0
# 140226     Lower Than A Level      NaN     0-35                     0
# 26167      Lower Than A Level    10-20     0-35                     0
# 66389      Lower Than A Level  90-100%    35-55                     2
# 35309      Lower Than A Level    10-20     0-35                     0
# 20958        HE Qualification    0-10%     0-35                     0
# 47998   A Level or Equivalent   20-30%     0-35                     0
#
#         studied_credits disability
# 12705                60          N
# 36179                60          N
# 159136               30          N
# 123142               60          N
# 140226               60          N
# 26167                60          N
# 66389               120          N
# 35309                60          N
# 20958                60          N
# 47998                30          N

# %%
assesmentsCoursesRegStudentInfo[assesmentsCoursesRegStudentInfo["id_student"] == 573152]
# Out:
#        code_module code_presentation  id_student  date_registration
# 123136         FFF             2013J      573152              -30.0  \
# 123137         FFF             2013J      573152              -30.0
# 123138         FFF             2013J      573152              -30.0
# 123139         FFF             2013J      573152              -30.0
# 123140         FFF             2013J      573152              -30.0
# 123141         FFF             2013J      573152              -30.0
# 123142         FFF             2013J      573152              -30.0
# 123143         FFF             2013J      573152              -30.0
# 123144         FFF             2013J      573152              -30.0
# 123145         FFF             2013J      573152              -30.0
# 123146         FFF             2013J      573152              -30.0
#
#         id_assessment  date_submitted assessment_type   date  weight
# 123136          34873              27             TMA   19.0    12.5  \
# 123137          34875              96             TMA   96.0    25.0
# 123138          34876             138             TMA  131.0    25.0
# 123139          34877             180             TMA  173.0    25.0
# 123140          34878              49             CMA  236.0     0.0
# 123141          34879              42             CMA  236.0     0.0
# 123142          34880             118             CMA  236.0     0.0
# 123143          34881             185             CMA  236.0     0.0
# 123144          34882             185             CMA  236.0     0.0
# 123145          34883             234             CMA  236.0     0.0
# 123146          34884             234             CMA  236.0     0.0
#
#         module_presentation_length gender            region
# 123136                         268      M  Yorkshire Region  \
# 123137                         268      M  Yorkshire Region
# 123138                         268      M  Yorkshire Region
# 123139                         268      M  Yorkshire Region
# 123140                         268      M  Yorkshire Region
# 123141                         268      M  Yorkshire Region
# 123142                         268      M  Yorkshire Region
# 123143                         268      M  Yorkshire Region
# 123144                         268      M  Yorkshire Region
# 123145                         268      M  Yorkshire Region
# 123146                         268      M  Yorkshire Region
#
#             highest_education imd_band age_band  num_of_prev_attempts
# 123136  A Level or Equivalent   20-30%     0-35                     0  \
# 123137  A Level or Equivalent   20-30%     0-35                     0
# 123138  A Level or Equivalent   20-30%     0-35                     0
# 123139  A Level or Equivalent   20-30%     0-35                     0
# 123140  A Level or Equivalent   20-30%     0-35                     0
# 123141  A Level or Equivalent   20-30%     0-35                     0
# 123142  A Level or Equivalent   20-30%     0-35                     0
# 123143  A Level or Equivalent   20-30%     0-35                     0
# 123144  A Level or Equivalent   20-30%     0-35                     0
# 123145  A Level or Equivalent   20-30%     0-35                     0
# 123146  A Level or Equivalent   20-30%     0-35                     0
#
#         studied_credits disability
# 123136               60          N
# 123137               60          N
# 123138               60          N
# 123139               60          N
# 123140               60          N
# 123141               60          N
# 123142               60          N
# 123143               60          N
# 123144               60          N
# 123145               60          N
# 123146               60          N
